# %%
from time import time as get_time
from utilities import fun_name, generate_array

from matplotlib import pyplot as plt

from sorts.bubble_sort import bubble_sort
from sorts.shaker_sort import shaker_sort
from sorts.comb_sort import comb_sort
from sorts.insertion_sort import insertion_sort
from sorts.selection_sort import selection_sort
from sorts.merge_sort import merge_sort
from sorts.quick_sort import quick_sort
from sorts.heap_sort import heap_sort

# %%
def get_top(results):
    return sorted(list(results.items()), key=lambda r: r[1][-1][-1])

def plot_top(top, unique_perc):
    fig = plt.figure(figsize=(16, 8))
    plt.title('Sorting algorithms speed comparison\n'
              + 'unique_perc = %s' % unique_perc, fontsize=20)
    
    colors = ['r', '#FF4500', 'm', 'b', '#1E90FF', 'g', '#9ACD32', '#999999']
    for i, (sort_fun, rs) in enumerate(top):
        sizes, _, times = zip(*rs)
        plt.plot(sizes, times,
                 linestyle = '-',
                 marker = 'o',
                 color=colors[i % len(colors)],
                 label=sort_fun)

    plt.xlabel('array_size', fontsize=20)
    plt.ylabel('time', fontsize=20)
    plt.grid(True)
    plt.legend(loc=0, fontsize=20)

    plt.show()

# %%
# TODO: calc avg speed over multiple arrays
# TODO: add partially sorted feature
def test_speed(sort_funs, array_sizes, unique_perc):
    print('SPEED TEST')
    print('SORT FUNS: %s' % list(map(fun_name, sort_funs)))
    print('UNIQUE PERCENTAGE: %s' % unique_perc)
     
    results = { fun_name(sort_fun) : [] for sort_fun in sort_funs }
    
    for array_size in array_sizes:
        print('\nARRAY SIZE: %s' % array_size)
        
        unique_count = int(array_size * unique_perc)
        lb = -(unique_count // 2) + (unique_count % 2 == 0)
        rb = unique_count // 2
        print('UNIQUE COUNT: %s' % unique_count)
        
        b = generate_array(array_size, lb, rb)
        for sort_fun in sort_funs:
            print('SORT: %s' % fun_name(sort_fun))
            
            a = b[:]

            start = get_time()
            sort_fun(a)
            end = get_time()

            results[fun_name(sort_fun)].append((array_size, unique_count, end - start))

            print('TIME: %s' % results[fun_name(sort_fun)][-1][-1])
        
        top = sorted([(sort_fun, results[sort_fun][-1][-1]) for sort_fun in results], key=lambda r: r[1])
        print('\nTOP:')
        for r in top:
            print('%s: %s' % r)
    
    print('\nSPEED TEST DONE!')
    return results

# %%
sort_funs = [
    quick_sort,
    heap_sort,
    comb_sort,
    
    merge_sort,
    
    selection_sort,
    insertion_sort,
    shaker_sort,
    bubble_sort,
]

array_sizes = [
    int(1e3),
    int(5e3),
    int(1e4),
    int(5e4),
    
    int(1e5),   
    int(3e5),
    int(5e5),
    
    int(8e5),
    int(1e6),
]

unique_perc_1 = 1

# %%
results_1 = test_speed(sort_funs[:3], array_sizes[:], unique_perc_1)
results_2 = test_speed([sort_funs[3]], array_sizes[:], unique_perc_1)
results_3 = test_speed(sort_funs[4:], array_sizes[:4], unique_perc_1)
# Out:
# SPEED TEST
# SORT FUNS: ['quick_sort', 'heap_sort', 'comb_sort']
# UNIQUE PERCENTAGE: 1
#
# ARRAY SIZE: 1000
# UNIQUE COUNT: 1000
# SORT: quick_sort
# TIME: 0.008457183837890625
# SORT: heap_sort
# TIME: 0.015067100524902344
# SORT: comb_sort
# TIME: 0.004767417907714844
#
# TOP:
# comb_sort: 0.004767417907714844
# quick_sort: 0.008457183837890625
# heap_sort: 0.015067100524902344
#
# ARRAY SIZE: 5000
# UNIQUE COUNT: 5000
# SORT: quick_sort
# TIME: 0.019745826721191406
# SORT: heap_sort
# TIME: 0.03514909744262695
# SORT: comb_sort
# TIME: 0.030747175216674805
#
# TOP:
# quick_sort: 0.019745826721191406
# comb_sort: 0.030747175216674805
# heap_sort: 0.03514909744262695
#
# ARRAY SIZE: 10000
# UNIQUE COUNT: 10000
# SORT: quick_sort
# TIME: 0.034174203872680664
# SORT: heap_sort
# TIME: 0.07484292984008789
# SORT: comb_sort
# TIME: 0.11884355545043945
#
# TOP:
# quick_sort: 0.034174203872680664
# heap_sort: 0.07484292984008789
# comb_sort: 0.11884355545043945
#
# ARRAY SIZE: 50000
# UNIQUE COUNT: 50000
# SORT: quick_sort
# TIME: 0.22987651824951172
# SORT: heap_sort
# TIME: 0.663931131362915
# SORT: comb_sort
# TIME: 0.6671164035797119
#
# TOP:
# quick_sort: 0.22987651824951172
# heap_sort: 0.663931131362915
# comb_sort: 0.6671164035797119
#
# ARRAY SIZE: 100000
# UNIQUE COUNT: 100000
# SORT: quick_sort
# TIME: 0.44190406799316406
# SORT: heap_sort
# TIME: 1.08182954788208
# SORT: comb_sort
# TIME: 1.2860362529754639
#
# TOP:
# quick_sort: 0.44190406799316406
# heap_sort: 1.08182954788208
# comb_sort: 1.2860362529754639
#
# ARRAY SIZE: 300000
# UNIQUE COUNT: 300000
# SORT: quick_sort
# TIME: 1.5845353603363037
# SORT: heap_sort
# TIME: 5.189921855926514
# SORT: comb_sort
# TIME: 5.070559740066528
#
# TOP:
# quick_sort: 1.5845353603363037
# comb_sort: 5.070559740066528
# heap_sort: 5.189921855926514
#
# ARRAY SIZE: 500000
# UNIQUE COUNT: 500000
# SORT: quick_sort
# TIME: 2.5927202701568604
# SORT: heap_sort
# TIME: 6.725082635879517
# SORT: comb_sort
# TIME: 8.75231647491455
#
# TOP:
# quick_sort: 2.5927202701568604
# heap_sort: 6.725082635879517
# comb_sort: 8.75231647491455
#
# ARRAY SIZE: 800000
# UNIQUE COUNT: 800000
# SORT: quick_sort
# TIME: 4.346187591552734
# SORT: heap_sort
# TIME: 10.699671030044556
# SORT: comb_sort
# TIME: 14.270481586456299
#
# TOP:
# quick_sort: 4.346187591552734
# heap_sort: 10.699671030044556
# comb_sort: 14.270481586456299
#
# ARRAY SIZE: 1000000
# UNIQUE COUNT: 1000000
# SORT: quick_sort
# TIME: 5.429887533187866
# SORT: heap_sort
# TIME: 14.279417276382446
# SORT: comb_sort
# TIME: 19.0501446723938
#
# TOP:
# quick_sort: 5.429887533187866
# heap_sort: 14.279417276382446
# comb_sort: 19.0501446723938
#
# SPEED TEST DONE!
# SPEED TEST
# SORT FUNS: ['merge_sort']
# UNIQUE PERCENTAGE: 1
#
# ARRAY SIZE: 1000
# UNIQUE COUNT: 1000
# SORT: merge_sort
# TIME: 0.006798505783081055
#
# TOP:
# merge_sort: 0.006798505783081055
#
# ARRAY SIZE: 5000
# UNIQUE COUNT: 5000
# SORT: merge_sort
# TIME: 0.043651580810546875
#
# TOP:
# merge_sort: 0.043651580810546875
#
# ARRAY SIZE: 10000
# UNIQUE COUNT: 10000
# SORT: merge_sort
# TIME: 0.1013479232788086
#
# TOP:
# merge_sort: 0.1013479232788086
#
# ARRAY SIZE: 50000
# UNIQUE COUNT: 50000
# SORT: merge_sort
# TIME: 1.116884708404541
#
# TOP:
# merge_sort: 1.116884708404541
#
# ARRAY SIZE: 100000
# UNIQUE COUNT: 100000
# SORT: merge_sort

# %%
top_1 = get_top(results_1)
plot_top(top_1, unique_perc)

# %%
top_2 = get_top(results_2)
plot_top(top_2, unique_perc)
plot_top(top_1 + top_2, unique_perc)

# %%
top_3 = get_top(results_3)
plot_top(top_3, unique_perc)

# %%
plot_top(top_1 + top_2 + top_3, unique_perc)

# %%
unique_perc_2 = 0.001
results_1_2 = test_speed(sort_funs[:3], array_sizes[:], unique_perc_2)
# Out:
# SPEED TEST
# SORT FUNS: ['quick_sort', 'heap_sort', 'comb_sort']
# UNIQUE PERCENTAGE: 0.001
#
# ARRAY SIZE: 1000
# UNIQUE COUNT: 1
# SORT: quick_sort
# TIME: 0.004973649978637695
# SORT: heap_sort
# TIME: 0.001714468002319336
# SORT: comb_sort
# TIME: 0.004316568374633789
#
# TOP:
# heap_sort: 0.001714468002319336
# comb_sort: 0.004316568374633789
# quick_sort: 0.004973649978637695
#
# ARRAY SIZE: 5000
# UNIQUE COUNT: 5
# SORT: quick_sort
# TIME: 0.02611517906188965
# SORT: heap_sort
# TIME: 0.035709381103515625
# SORT: comb_sort
# TIME: 0.022968053817749023
#
# TOP:
# comb_sort: 0.022968053817749023
# quick_sort: 0.02611517906188965
# heap_sort: 0.035709381103515625
#
# ARRAY SIZE: 10000
# UNIQUE COUNT: 10
# SORT: quick_sort
# TIME: 0.035546064376831055
# SORT: heap_sort
# TIME: 0.0705101490020752
# SORT: comb_sort
# TIME: 0.06337237358093262
#
# TOP:
# quick_sort: 0.035546064376831055
# comb_sort: 0.06337237358093262
# heap_sort: 0.0705101490020752
#
# ARRAY SIZE: 50000
# UNIQUE COUNT: 50
# SORT: quick_sort
# TIME: 0.20923161506652832
# SORT: heap_sort
# TIME: 0.5362544059753418
# SORT: comb_sort
# TIME: 0.6740598678588867
#
# TOP:
# quick_sort: 0.20923161506652832
# heap_sort: 0.5362544059753418
# comb_sort: 0.6740598678588867
#
# ARRAY SIZE: 100000
# UNIQUE COUNT: 100
# SORT: quick_sort
# TIME: 0.4481208324432373
# SORT: heap_sort
# TIME: 0.9882745742797852
# SORT: comb_sort
# TIME: 0.7760100364685059
#
# TOP:
# quick_sort: 0.4481208324432373
# comb_sort: 0.7760100364685059
# heap_sort: 0.9882745742797852
#
# ARRAY SIZE: 300000
# UNIQUE COUNT: 300
# SORT: quick_sort
# TIME: 1.3594295978546143
# SORT: heap_sort
# TIME: 3.437438488006592
# SORT: comb_sort
# TIME: 3.13077449798584
#
# TOP:
# quick_sort: 1.3594295978546143
# comb_sort: 3.13077449798584
# heap_sort: 3.437438488006592
#
# ARRAY SIZE: 500000
# UNIQUE COUNT: 500
# SORT: quick_sort
# TIME: 2.4787237644195557
# SORT: heap_sort
# TIME: 5.834482669830322
# SORT: comb_sort
# TIME: 5.906957149505615
#
# TOP:
# quick_sort: 2.4787237644195557
# heap_sort: 5.834482669830322
# comb_sort: 5.906957149505615
#
# ARRAY SIZE: 800000
# UNIQUE COUNT: 800
# SORT: quick_sort
# TIME: 4.118265628814697
# SORT: heap_sort
# TIME: 10.109554052352905
# SORT: comb_sort
# TIME: 10.627400875091553
#
# TOP:
# quick_sort: 4.118265628814697
# heap_sort: 10.109554052352905
# comb_sort: 10.627400875091553
#
# ARRAY SIZE: 1000000
# UNIQUE COUNT: 1000
# SORT: quick_sort
# TIME: 5.321825265884399
# SORT: heap_sort
# TIME: 12.806214332580566
# SORT: comb_sort
# TIME: 13.993011474609375
#
# TOP:
# quick_sort: 5.321825265884399
# heap_sort: 12.806214332580566
# comb_sort: 13.993011474609375
#
# SPEED TEST DONE!

# %%
top_1_2 = get_top(results_1_2)
plot_top(top_1_2, unique_perc_2)

# %%
plot_top(up_top_1 + top_1, '%s | %s' % (unique_perc_1, unique_perc_2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-0d96d0ae352e> in <module>
# ----> 1 plot_top(up_top_1 + top_1, '1 | 0.001')
#
# NameError: name 'top_1' is not defined
